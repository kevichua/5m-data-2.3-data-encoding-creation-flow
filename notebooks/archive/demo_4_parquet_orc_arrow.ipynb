# %% [markdown]
# # Data Encoding, Decoding and Flow

# %% [markdown]
# ## Apache Parquet, ORC and Arrow
#
# We can easily read (decode) and write (encode) data from and to Parquet, ORC and Arrow files interchangeably. The `pyarrow` library allows us to read a Parquet or ORC file into a `pyarrow.Table` object, which is a columnar data structure that can be converted to a Pandas DataFrame. We can also write a `pyarrow.Table` to a Parquet or ORC file.
#
# Parquet has the following types:
#
# - boolean: 1 bit boolean
# - int32: 32 bit signed ints
# - int64: 64 bit signed ints
# - int96: 96 bit signed ints
# - float: IEEE 32-bit floating point values
# - double: IEEE 64-bit floating point values
# - byte_array: arbitrarily long byte arrays
# - fixed_len_byte_array: fixed length byte arrays
# - string: UTF-8 encoded strings
# - enum: enumeration of strings
# - temporal: a logical date type
#
# ORC has the following types:
#
# - boolean: 1 bit boolean
# - tinyint: 8 bit signed ints
# - smallint: 16 bit signed ints
# - int: 32 bit signed ints
# - bigint: 64 bit signed ints
# - float: IEEE 32-bit floating point values
# - double: IEEE 64-bit floating point values
# - string: UTF-8 encoded strings
# - char: ASCII strings
# - varchar: UTF-8 strings
# - binary: byte arrays
# - timestamp: a logical date type
# - date: a logical date type
# - decimal: arbitrary precision decimals
# - list: an ordered collection of objects
# - map: a collection of key-value pairs
# - struct: an ordered collection of named fields
# - union: a list of types
#
# ![overview-diagram](../assets/diagram-2.png)
#
# ### Reading (Decoding) and Writing (Encoding) a Parquet File
#
# Let's look at how to decode and encode a Parquet file with mock customers data.

# %%
import pyarrow as pa
import pyarrow.parquet as pq

# %%
table = pq.read_table('../data/userdata1.parquet')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 table = pq.read_table('../data/userdata1.parquet')
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pyarrow/parquet/core.py:1843, in read_table(source, columns, use_threads, schema, use_pandas_metadata, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, filesystem, filters, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
#    1831 def read_table(source, *, columns=None, use_threads=True,
#    1832                schema=None, use_pandas_metadata=False, read_dictionary=None,
#    1833                binary_type=None, list_type=None, memory_map=False, buffer_size=0,
#    (...)   1839                page_checksum_verification=False,
#    1840                arrow_extensions_enabled=True):
#    1842     try:
# -> 1843         dataset = ParquetDataset(
#    1844             source,
#    1845             schema=schema,
#    1846             filesystem=filesystem,
#    1847             partitioning=partitioning,
#    1848             memory_map=memory_map,
#    1849             read_dictionary=read_dictionary,
#    1850             binary_type=binary_type,
#    1851             list_type=list_type,
#    1852             buffer_size=buffer_size,
#    1853             filters=filters,
#    1854             ignore_prefixes=ignore_prefixes,
#    1855             pre_buffer=pre_buffer,
#    1856             coerce_int96_timestamp_unit=coerce_int96_timestamp_unit,
#    1857             decryption_properties=decryption_properties,
#    1858             thrift_string_size_limit=thrift_string_size_limit,
#    1859             thrift_container_size_limit=thrift_container_size_limit,
#    1860             page_checksum_verification=page_checksum_verification,
#    1861             arrow_extensions_enabled=arrow_extensions_enabled,
#    1862         )
#    1863     except ImportError:
#    1864         # fall back on ParquetFile for simple cases when pyarrow.dataset
#    1865         # module is not available
#    1866         if filters is not None:
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pyarrow/parquet/core.py:1424, in ParquetDataset.__init__(self, path_or_paths, filesystem, schema, filters, read_dictionary, binary_type, list_type, memory_map, buffer_size, partitioning, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, page_checksum_verification, arrow_extensions_enabled)
#    1420 if partitioning == "hive":
#    1421     partitioning = ds.HivePartitioning.discover(
#    1422         infer_dictionary=True)
# -> 1424 self._dataset = ds.dataset(path_or_paths, filesystem=filesystem,
#    1425                            schema=schema, format=parquet_format,
#    1426                            partitioning=partitioning,
#    1427                            ignore_prefixes=ignore_prefixes)
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pyarrow/dataset.py:790, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     779 kwargs = dict(
#     780     schema=schema,
#     781     filesystem=filesystem,
#    (...)    786     selector_ignore_prefixes=ignore_prefixes
#     787 )
#     789 if _is_path_like(source):
# --> 790     return _filesystem_dataset(source, **kwargs)
#     791 elif isinstance(source, (tuple, list)):
#     792     if all(_is_path_like(elem) or isinstance(elem, FileInfo) for elem in source):
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pyarrow/dataset.py:472, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     470         fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     471 else:
# --> 472     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#     474 options = FileSystemFactoryOptions(
#     475     partitioning=partitioning,
#     476     partition_base_dir=partition_base_dir,
#     477     exclude_invalid_files=exclude_invalid_files,
#     478     selector_ignore_prefixes=selector_ignore_prefixes
#     479 )
#     480 factory = FileSystemDatasetFactory(fs, paths_or_selector, format, options)
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pyarrow/dataset.py:437, in _ensure_single_source(path, filesystem)
#     435     paths_or_selector = [path]
#     436 else:
# --> 437     raise FileNotFoundError(path)
#     439 return filesystem, paths_or_selector
#
# FileNotFoundError: ../data/userdata1.parquet

# %%
table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 table
#
# NameError: name 'table' is not defined

# %%
table.schema
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 table.schema
#
# NameError: name 'table' is not defined

# %%
metadata = pq.read_metadata('../data/userdata1.parquet')

metadata
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 metadata = pq.read_metadata('../data/userdata1.parquet')
#       3 metadata
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pyarrow/parquet/core.py:2344, in read_metadata(where, memory_map, decryption_properties, filesystem)
#    2342 file_ctx = nullcontext()
#    2343 if filesystem is not None:
# -> 2344     file_ctx = where = filesystem.open_input_file(where)
#    2346 with file_ctx:
#    2347     file = ParquetFile(where, memory_map=memory_map,
#    2348                        decryption_properties=decryption_properties)
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pyarrow/_fs.pyx:814, in pyarrow._fs.FileSystem.open_input_file()
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/miniconda3/envs/bde/lib/python3.11/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# FileNotFoundError: [Errno 2] Failed to open local file '../data/userdata1.parquet'. Detail: [errno 2] No such file or directory

# %%
metadata.schema
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 metadata.schema
#
# NameError: name 'metadata' is not defined

# %%
metadata.row_group(0).column(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 metadata.row_group(0).column(10)
#
# NameError: name 'metadata' is not defined

# %% [markdown]
# Select the first 3 rows of the table:

# %%
table.take([0,1,2])

# %% [markdown]
# Convert a Table to a DataFrame:

# %%
df = table.to_pandas()

# %%
df

# %% [markdown]
# You can convert the DataFrame back to a Table (note we're using the method from `pa` which is pyarrow):

# %%
new_table = pa.Table.from_pandas(df)

new_table

# %% [markdown]
# You can write the table back to a Parquet file:

# %%
pq.write_table(new_table, "../data/userdata2.parquet")

# %% [markdown]
# > 1. How many males and females are there?
# >
# > 2. What is the average salary for customers from China?
# >
# > 3. Create a new column `full_name` which combines `first_name` and `last_name` with a space in between in the dataframe. Then convert it back to a new Table and write it to a Parquet file.

# %% [markdown]
# ### Reading (Decoding) and Writing (Encoding) an ORC File
#
# Let's look at how to decode and encode an ORC file with mock data.

# %%
import pyarrow as pa
from pyarrow import orc

# %%
table2 = orc.read_table('../data/userdata1.1.orc')

# %%
table2

# %%
df2 = table2.to_pandas()

df2

# %% [markdown]
# You can write the table back to an ORC file:

# %%
orc.write_table(table2, "../data/file2.orc")
